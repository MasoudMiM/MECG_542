# %%
import pandas as pd

# %% [markdown]
# Importing a CSV file ( Airfoil Noise data set )

# %%
# change the url to the link to the data set you want to import
url1 = 'https://raw.githubusercontent.com/MasoudMiM/MECG_542/master/Airfoil_Noise/Data.csv'   # Link to the Airfoil Noise data set
df1 = pd.read_csv(url, header=None, names=['Frequency (Hz)','Attack_Angle (deg)','Cord (m)',
                                          'FS_Velocity (m/s)','SSD_Thickness (m)','Sound_Pressure_Level (dB)'])

# Dataset is now stored in a Pandas Dataframe
df1.head()
# Out:
#    Frequency (Hz)  Attack_Angle (deg)  Cord (m)  FS_Velocity (m/s)  \
# 0             800                 0.0    0.3048               71.3
# 1            1000                 0.0    0.3048               71.3
# 2            1250                 0.0    0.3048               71.3
# 3            1600                 0.0    0.3048               71.3
# 4            2000                 0.0    0.3048               71.3
#
#    SSD_Thickness (m)  Sound_Pressure_Level (dB)
# 0           0.002663                    126.201
# 1           0.002663                    125.201
# 2           0.002663                    125.951
# 3           0.002663                    127.591
# 4           0.002663                    127.461

# %% [markdown]
# Importing an Excel file ( EPA Green Vehicle data set 2020 )

# %%
xlsx = pd.ExcelFile('https://raw.githubusercontent.com/MasoudMiM/MECG_542/master/EPA_Green_Vehicle_Guide_2020/Data.xlsx')
df2 = pd.read_excel(xlsx, 'Sheet1')

# Dataset is now stored in a Pandas Dataframe
df2.head()
# Out:
#        Model  Displ  Cyl       Trans Drive      Fuel Cert Region       Stnd  \
# 0  ACURA ILX    2.4  4.0       AMS-8   2WD  Gasoline          CA  L3ULEV125
# 1  ACURA ILX    2.4  4.0       AMS-8   2WD  Gasoline          FA     T3B125
# 2  ACURA MDX    3.0  6.0       AMS-7   4WD  Gasoline          CA  L3ULEV125
# 3  ACURA MDX    3.0  6.0       AMS-7   4WD  Gasoline          FA     T3B125
# 4  ACURA MDX    3.5  6.0  SemiAuto-9   2WD  Gasoline          CA  L3ULEV125
#
#              Stnd Description  Underhood ID  Veh Class  Air Pollution Score  \
# 0  California LEV-III ULEV125  LHNXV02.4KH3  small car                    3
# 1      Federal Tier 3 Bin 125  LHNXV02.4KH3  small car                    3
# 2  California LEV-III ULEV125  LHNXV03.0ABC  small SUV                    3
# 3      Federal Tier 3 Bin 125  LHNXV03.0ABC  small SUV                    3
# 4  California LEV-III ULEV125  LHNXV03.5PBM  small SUV                    3
#
# ...
